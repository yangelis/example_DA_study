# %% [markdown]
# ### Import modules

# %%
# Standard imports
import pandas as pd
import sys 
import os
import seaborn as sns
import os
import shutil

# Local imports
sys.path.insert(1, os.path.join(sys.path[0], '..'))
import analysis_functions 

# Apply better style
analysis_functions.apply_heatmap_style()

# %% [markdown]
# ### Collider 2023, 0.5/0.5

# %%
# Define study
STUDY_NAME = "tune_scan_2023"
COLLIDER = "collider_00"
PARQUET_PATH = f"../../scans/{STUDY_NAME}/da.parquet"
CONF_MAD_PATH = f"../../scans/{STUDY_NAME}/{COLLIDER}/config.yaml"
CONF_COLLIDER_PATH = f"../../scans/{STUDY_NAME}/{COLLIDER}/xtrack_0004/config.yaml"

# SAve study on EOS
SAVE_STUDY_EOS = False

# %%
# Load dataframe
df = pd.read_parquet(f"../../scans/{STUDY_NAME}/da.parquet")

# Round all numbers to 3 decimals
df = df.round(3)

# Keep only relevant collider
df = df.reset_index(level=1)
df = df[df["name base collider"] == COLLIDER]

df
# Out:
#                     name base collider  normalized amplitude in xy-plane  \
# beam  qx     qy
# lhcb1 62.305 60.309        collider_00                             3.562
#              60.310        collider_00                             3.844
#              60.311        collider_00                             3.562
#              60.312        collider_00                             4.688
#              60.313        collider_00                             4.438
# ...                                ...                               ...
#       62.323 60.328        collider_00                             2.438
#              60.329        collider_00                             2.000
#       62.324 60.328        collider_00                             2.750
#              60.329        collider_00                             2.125
#       62.325 60.329        collider_00                             2.438
#
#                          qx      qy   dqx   dqy  i_bunch_b1  i_bunch_b2  \
# beam  qx     qy
# lhcb1 62.305 60.309  62.305  60.309  15.0  15.0       411.0       410.0
#              60.310  62.305  60.310  15.0  15.0       411.0       410.0
#              60.311  62.305  60.311  15.0  15.0       411.0       410.0
#              60.312  62.305  60.312  15.0  15.0       411.0       410.0
#              60.313  62.305  60.313  15.0  15.0       411.0       410.0
# ...                     ...     ...   ...   ...         ...         ...
#       62.323 60.328  62.323  60.328  15.0  15.0       411.0       410.0
#              60.329  62.323  60.329  15.0  15.0       411.0       410.0
#       62.324 60.328  62.324  60.328  15.0  15.0       411.0       410.0
#              60.329  62.324  60.329  15.0  15.0       411.0       410.0
#       62.325 60.329  62.325  60.329  15.0  15.0       411.0       410.0
#
#                      num_particles_per_bunch
# beam  qx     qy
# lhcb1 62.305 60.309             1.150000e+11
#              60.310             1.150000e+11
#              60.311             1.150000e+11
#              60.312             1.150000e+11
#              60.313             1.150000e+11
# ...                                      ...
#       62.323 60.328             1.150000e+11
#              60.329             1.150000e+11
#       62.324 60.328             1.150000e+11
#              60.329             1.150000e+11
#       62.325 60.329             1.150000e+11
#
# [231 rows x 9 columns]

# %%
# Reshape for plotting
df_to_plot = df.pivot(index="qy", columns="qx", values="normalized amplitude in xy-plane")
df_to_plot
# Out:
# qx      62.305  62.306  62.307  62.308  62.309  62.310  62.311  62.312  \
# qy
# 60.309   3.562     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
# 60.312     NaN     NaN     NaN     NaN
# 60.313     NaN     NaN     NaN     NaN
# 60.314     NaN     NaN     NaN     NaN
# 60.315     NaN     NaN     NaN     NaN
# 60.316     NaN     NaN     NaN     NaN
# 60.317     NaN     NaN     NaN     NaN
# 60.318     NaN     NaN     NaN     NaN
# 60.319     NaN     NaN     NaN     NaN
# 60.320     NaN     NaN     NaN     NaN
# 60.321     NaN     NaN     NaN     NaN
# 60.322     NaN     NaN     NaN     NaN
# 60.323     NaN     NaN     NaN     NaN
# 60.324     NaN     NaN     NaN     NaN
# 60.325     NaN     NaN     NaN     NaN
# 60.326   3.750     NaN     NaN     NaN
# 60.327   3.438   3.156     NaN     NaN
# 60.328   2.438   2.438   2.750     NaN
# 60.329   2.438   2.000   2.125   2.438
#
# [21 rows x 21 columns]

# %%
# Load configuration files
conf_mad = analysis_functions.load_config(CONF_MAD_PATH)['config_mad']
conf_collider = analysis_functions.load_config(CONF_COLLIDER_PATH)["config_collider"]

# %%
analysis_functions.plot_heatmap(
    df_to_plot,
    STUDY_NAME + '_' + COLLIDER,
    link="TODO",
    plot_contours=True,
    conf_mad=conf_mad,
    conf_collider=conf_collider,
    type_crossing="flatvh",
    betx=0.485,
    bety=0.485,
)

# %%
if SAVE_STUDY_EOS:
    path_archive, path_EOS = analysis_functions.copy_study_on_eos(STUDY_NAME)
    #analysis_functions.archive_and_clean(path_archive, path_EOS)

# %% [markdown]
# ### Collider 2023, 0.2/0.2

# %%
# Define study
STUDY_NAME = "tune_scan_2023"
COLLIDER = "collider_01"
PARQUET_PATH = f"../../scans/{STUDY_NAME}/da.parquet"
CONF_MAD_PATH = f"../../scans/{STUDY_NAME}/{COLLIDER}/config.yaml"
CONF_COLLIDER_PATH = f"../../scans/{STUDY_NAME}/{COLLIDER}/xtrack_0004/config.yaml"

# SAve study on EOS
SAVE_STUDY_EOS = False
# Load dataframe
df = pd.read_parquet(f"../../scans/{STUDY_NAME}/da.parquet")

# Round all numbers to 3 decimals
df = df.round(3)

# Keep only relevant collider
df = df.reset_index(level=1)
df = df[df["name base collider"] == COLLIDER]

df
# Reshape for plotting
df_to_plot = df.pivot(index="qy", columns="qx", values="normalized amplitude in xy-plane")
df_to_plot
# Load configuration files
conf_mad = analysis_functions.load_config(CONF_MAD_PATH)['config_mad']
conf_collider = analysis_functions.load_config(CONF_COLLIDER_PATH)["config_collider"]
analysis_functions.plot_heatmap(
    df_to_plot,
    STUDY_NAME + '_' + COLLIDER,
    link="TODO",
    plot_contours=True,
    conf_mad=conf_mad,
    conf_collider=conf_collider,
    type_crossing="flatvh",
    betx=0.2,
    bety=0.2,
)
if SAVE_STUDY_EOS:
    path_archive, path_EOS = analysis_functions.copy_study_on_eos(STUDY_NAME)
    #analysis_functions.archive_and_clean(path_archive, path_EOS)

# %% [markdown]
# ### Collider 2024, 0.5/0.5

# %%
# Define study
STUDY_NAME = "tune_scan_2024"
COLLIDER = "collider_00"
PARQUET_PATH = f"../../scans/{STUDY_NAME}/da.parquet"
CONF_MAD_PATH = f"../../scans/{STUDY_NAME}/{COLLIDER}/config.yaml"
CONF_COLLIDER_PATH = f"../../scans/{STUDY_NAME}/{COLLIDER}/xtrack_0004/config.yaml"

# SAve study on EOS
SAVE_STUDY_EOS = False
# Load dataframe
df = pd.read_parquet(f"../../scans/{STUDY_NAME}/da.parquet")

# Round all numbers to 3 decimals
df = df.round(3)

# Keep only relevant collider
df = df.reset_index(level=1)
df = df[df["name base collider"] == COLLIDER]

df
# Reshape for plotting
df_to_plot = df.pivot(index="qy", columns="qx", values="normalized amplitude in xy-plane")
df_to_plot
# Load configuration files
conf_mad = analysis_functions.load_config(CONF_MAD_PATH)['config_mad']
conf_collider = analysis_functions.load_config(CONF_COLLIDER_PATH)["config_collider"]
analysis_functions.plot_heatmap(
    df_to_plot,
    STUDY_NAME + '_' + COLLIDER,
    link="TODO",
    plot_contours=True,
    conf_mad=conf_mad,
    conf_collider=conf_collider,
    type_crossing="flathv",
    betx=0.5,
    bety=0.5,
)
if SAVE_STUDY_EOS:
    path_archive, path_EOS = analysis_functions.copy_study_on_eos(STUDY_NAME)
    #analysis_functions.archive_and_clean(path_archive, path_EOS)

# %% [markdown]
# ### Collider 2024, 0.5/0.15

# %%
# Define study
STUDY_NAME = "tune_scan_2024"
COLLIDER = "collider_01"
PARQUET_PATH = f"../../scans/{STUDY_NAME}/da.parquet"
CONF_MAD_PATH = f"../../scans/{STUDY_NAME}/{COLLIDER}/config.yaml"
CONF_COLLIDER_PATH = f"../../scans/{STUDY_NAME}/{COLLIDER}/xtrack_0004/config.yaml"

# SAve study on EOS
SAVE_STUDY_EOS = False
# Load dataframe
df = pd.read_parquet(f"../../scans/{STUDY_NAME}/da.parquet")

# Round all numbers to 3 decimals
df = df.round(3)

# Keep only relevant collider
df = df.reset_index(level=1)
df = df[df["name base collider"] == COLLIDER]

df
# Reshape for plotting
df_to_plot = df.pivot(index="qy", columns="qx", values="normalized amplitude in xy-plane")
df_to_plot
# Load configuration files
conf_mad = analysis_functions.load_config(CONF_MAD_PATH)['config_mad']
conf_collider = analysis_functions.load_config(CONF_COLLIDER_PATH)["config_collider"]
analysis_functions.plot_heatmap(
    df_to_plot,
    STUDY_NAME + '_' + COLLIDER,
    link="TODO",
    plot_contours=True,
    conf_mad=conf_mad,
    conf_collider=conf_collider,
    type_crossing="flathv",
    betx=0.5,
    bety=0.15,
)
if SAVE_STUDY_EOS:
    path_archive, path_EOS = analysis_functions.copy_study_on_eos(STUDY_NAME)
    #analysis_functions.archive_and_clean(path_archive, path_EOS)
