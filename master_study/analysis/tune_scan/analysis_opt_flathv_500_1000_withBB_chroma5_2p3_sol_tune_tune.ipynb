# %% [markdown]
# ### Import modules

# %%
# Standard imports
import pandas as pd
import sys 
import os
import seaborn as sns
import os
import shutil

# Local imports
sys.path.insert(1, os.path.join(sys.path[0], '..'))
import analysis_functions 

# Apply better style
analysis_functions.apply_heatmap_style()

# Define study
STUDY_NAME = "opt_flathv_500_1000_withBB_chroma5_2p3_sol_tune_tune"
PARQUET_PATH = f"../../scans/{STUDY_NAME}/da.parquet"
CONF_MAD_PATH = f"../../scans/{STUDY_NAME}/base_collider/config.yaml"
CONF_COLLIDER_PATH = f"../../scans/{STUDY_NAME}/base_collider/xtrack_0004/config.yaml"

# SAve study on EOS
SAVE_STUDY_EOS = False

# %% [markdown]
# ### Load data

# %%
# Load dataframe
df = pd.read_parquet(f"../../scans/{STUDY_NAME}/da.parquet")

# Round all numbers to 3 decimals
df = df.round(3)

df
# Out:
#                      normalized amplitude in xy-plane      qx      qy
# beam  qx     qy
# lhcb1 62.305 60.309                             2.938  62.305  60.309  \
#              60.310                             2.750  62.305  60.310
#              60.311                             3.094  62.305  60.311
#              60.312                             3.094  62.305  60.312
#              60.313                             3.000  62.305  60.313
# ...                                               ...     ...     ...
#       62.323 60.328                             5.188  62.323  60.328
#              60.329                             4.125  62.323  60.329
#       62.324 60.328                             4.969  62.324  60.328
#              60.329                             4.062  62.324  60.329
#       62.325 60.329                             4.438  62.325  60.329
#
#                      i_bunch_b1  i_bunch_b2  num_particles_per_bunch
# beam  qx     qy
# lhcb1 62.305 60.309      1963.0      1963.0             2.300000e+11
#              60.310      1963.0      1963.0             2.300000e+11
#              60.311      1963.0      1963.0             2.300000e+11
#              60.312      1963.0      1963.0             2.300000e+11
#              60.313      1963.0      1963.0             2.300000e+11
# ...                         ...         ...                      ...
#       62.323 60.328      1963.0      1963.0             2.300000e+11
#              60.329      1963.0      1963.0             2.300000e+11
#       62.324 60.328      1963.0      1963.0             2.300000e+11
#              60.329      1963.0      1963.0             2.300000e+11
#       62.325 60.329      1963.0      1963.0             2.300000e+11
#
# [231 rows x 6 columns]

# %%
# Reshape for plotting
df_to_plot = df.pivot(index="qy", columns="qx", values="normalized amplitude in xy-plane")
df_to_plot
# Out:
# qx      62.305  62.306  62.307  62.308  62.309  62.310  62.311  62.312
# qy
# 60.309   2.938     NaN     NaN     NaN     NaN     NaN     NaN     NaN  \
# 60.310   2.750   3.062     NaN     NaN     NaN     NaN     NaN     NaN
# 60.311   3.094   2.906   3.969     NaN     NaN     NaN     NaN     NaN
# 60.312   3.094   3.656   4.156   4.562     NaN     NaN     NaN     NaN
# 60.313   3.000   3.000   3.188   4.500   4.656     NaN     NaN     NaN
# 60.314   3.219   3.062   3.438   4.312   4.750   4.281     NaN     NaN
# 60.315   2.656   2.906   3.625   4.625   4.281   4.625   4.062     NaN
# 60.316   3.375   2.938   4.344   4.562   5.094   4.500   4.406   4.062
# 60.317   3.125   3.500   4.125   4.688   4.750   4.344   4.375   4.438
# 60.318   3.250   3.938   3.875   4.250   4.656   4.625   4.344   4.844
# 60.319   3.156   3.625   4.125   4.469   4.375   4.500   4.344   4.219
# 60.320   3.219   3.781   3.906   4.594   4.719   4.594   4.719   4.531
# 60.321   3.344   3.344   4.562   4.188   4.406   4.656   4.562   4.406
# 60.322   3.438   3.719   3.688   3.938   4.594   4.500   4.781   4.531
# 60.323   3.438   3.438   3.750   4.562   4.625   4.438   4.250   4.156
# 60.324   3.094   3.312   3.062   4.375   4.312   4.875   4.375   4.594
# 60.325   3.219   3.219   3.625   4.375   4.531   4.469   4.656   4.406
# 60.326   3.094   3.250   3.625   4.344   4.375   4.438   4.156   4.062
# 60.327   3.281   3.438   2.906   3.469   4.281   4.281   4.438   3.969
# 60.328   3.250   2.875   3.000   3.562   4.031   4.094   4.156   4.094
# 60.329   3.031   3.094   3.281   3.219   3.531   3.812   3.812   3.812
#
# qx      62.313  62.314  ...  62.316  62.317  62.318  62.319  62.320  62.321
# qy                      ...
# 60.309     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN  \
# 60.310     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.311     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.312     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.313     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.314     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.315     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.316     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.317   5.344     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.318   5.000   6.000  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.319   5.125   5.719  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.320   5.750   5.844  ...   5.750     NaN     NaN     NaN     NaN     NaN
# 60.321   5.906   5.781  ...   6.031   7.156     NaN     NaN     NaN     NaN
# 60.322   5.594   5.594  ...   6.719   6.688   7.531     NaN     NaN     NaN
# 60.323   5.375   5.844  ...   6.312   6.719   7.094   7.375     NaN     NaN
# 60.324   5.531   5.719  ...   5.781   6.281   6.781   7.125   7.000     NaN
# 60.325   5.625   5.469  ...   5.531   5.906   6.188   6.562   6.969   6.625
# 60.326   4.688   5.438  ...   5.406   5.000   5.469   5.750   5.844   5.781
# 60.327   4.531   4.625  ...   4.656   4.844   4.969   5.031   5.094   5.250
# 60.328   4.344   4.219  ...   4.312   4.469   4.375   4.469   4.562   4.750
# 60.329   3.688   4.062  ...   3.469   4.062   3.938   4.219   3.844   3.938
#
# qx      62.322  62.323  62.324  62.325
# qy
# 60.309     NaN     NaN     NaN     NaN
# 60.310     NaN     NaN     NaN     NaN
# 60.311     NaN     NaN     NaN     NaN
# 60.312     NaN     NaN     NaN     NaN
# 60.313     NaN     NaN     NaN     NaN
# 60.314     NaN     NaN     NaN     NaN
# 60.315     NaN     NaN     NaN     NaN
# 60.316     NaN     NaN     NaN     NaN
# 60.317     NaN     NaN     NaN     NaN
# 60.318     NaN     NaN     NaN     NaN
# 60.319     NaN     NaN     NaN     NaN
# 60.320     NaN     NaN     NaN     NaN
# 60.321     NaN     NaN     NaN     NaN
# 60.322     NaN     NaN     NaN     NaN
# 60.323     NaN     NaN     NaN     NaN
# 60.324     NaN     NaN     NaN     NaN
# 60.325     NaN     NaN     NaN     NaN
# 60.326   6.188     NaN     NaN     NaN
# 60.327   5.531   5.500     NaN     NaN
# 60.328   4.500   5.188   4.969     NaN
# 60.329   4.125   4.125   4.062   4.438
#
# [21 rows x 21 columns]

# %%
# Load configuration files
conf_mad = analysis_functions.load_config(CONF_MAD_PATH)['config_mad']
conf_collider = analysis_functions.load_config(CONF_COLLIDER_PATH)["config_collider"]

# %% [markdown]
# ### Plot heatmap for tune-tune scan

# %%
analysis_functions.plot_heatmap(df_to_plot, STUDY_NAME, link="https://cernbox.cern.ch/s/JCCMjYO4GBa0T7e", plot_contours=True, conf_mad=conf_mad, conf_collider=conf_collider)

# %% [markdown]
# ### Save study on EOS

# %%
if SAVE_STUDY_EOS:
    path_archive, path_EOS = analysis_functions.copy_study_on_eos(STUDY_NAME)
    #analysis_functions.archive_and_clean(path_archive, path_EOS)
